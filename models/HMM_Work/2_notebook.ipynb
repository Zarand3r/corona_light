# %% [markdown]
# # Problem 2

# %% [markdown]
# In this Jupyter notebook, we visualize how HMMs work. This visualization corresponds to problem 2 in set 6.
#
# Assuming your HMM module is complete and saved at the correct location, you can simply run all cells in the notebook without modification.

# %%
import os
import numpy as np
from IPython.display import HTML

from HMM import unsupervised_HMM
from HMM_helper import (
    text_to_wordcloud,
    states_to_wordclouds,
    parse_observations,
    sample_sentence,
    visualize_sparsities,
    animate_emission
)

# %% [markdown]
# ## Visualization of the dataset

# %% [markdown]
# We will be using the Constitution as our dataset. First, we visualize the entirety of the Constitution as a wordcloud:

# %%
text = open(os.path.join(os.getcwd(), 'data/constitution.txt')).read()
wordcloud = text_to_wordcloud(text, title='Constitution')

# %% [markdown]
# ## Training an HMM

# %% [markdown]
# Now we train an HMM on our dataset. We use 10 hidden states and train over 100 iterations:

# %%
obs, obs_map = parse_observations(text)
#hmm8 = unsupervised_HMM(obs, 10, 100)

# %%
obs_map
# Out:
# {'we': 0,
#  'the': 1,
#  'people': 2,
#  'of': 3,
#  'united': 4,
#  'states': 5,
#  'in': 6,
#  'order': 7,
#  'to': 8,
#  'form': 9,
#  'a': 10,
#  'more': 11,
#  'perfect': 12,
#  'union': 13,
#  'establish': 14,
#  'justice': 15,
#  'insure': 16,
#  'domestic': 17,
#  'tranquility': 18,
#  'provide': 19,
#  'for': 20,
#  'common': 21,
#  'defence': 22,
#  'promote': 23,
#  'general': 24,
#  'welfare': 25,
#  'and': 26,
#  'secure': 27,
#  'blessings': 28,
#  'liberty': 29,
#  'ourselves': 30,
#  'our': 31,
#  'posterity': 32,
#  'do': 33,
#  'ordain': 34,
#  'this': 35,
#  'constitution': 36,
#  'america': 37,
#  'article': 38,
#  'i': 39,
#  'section': 40,
#  '1': 41,
#  'all': 42,
#  'legislative': 43,
#  'powers': 44,
#  'herein': 45,
#  'granted': 46,
#  'shall': 47,
#  'be': 48,
#  'vested': 49,
#  'congress': 50,
#  'which': 51,
#  'consist': 52,
#  'senate': 53,
#  'house': 54,
#  'representatives': 55,
#  '2': 56,
#  'composed': 57,
#  'members': 58,
#  'chosen': 59,
#  'every': 60,
#  'second': 61,
#  'year': 62,
#  'by': 63,
#  'several': 64,
#  'electors': 65,
#  'each': 66,
#  'state': 67,
#  'have': 68,
#  'qualifications': 69,
#  'requisite': 70,
#  'most': 71,
#  'numerous': 72,
#  'branch': 73,
#  'legislature': 74,
#  'no': 75,
#  'person': 76,
#  'representative': 77,
#  'who': 78,
#  'not': 79,
#  'attained': 80,
#  'age': 81,
#  'twenty': 82,
#  'five': 83,
#  'years': 84,
#  'been': 85,
#  'seven': 86,
#  'citizen': 87,
#  'when': 88,
#  'elected': 89,
#  'an': 90,
#  'inhabitant': 91,
#  'that': 92,
#  'he': 93,
#  'direct': 94,
#  'taxes': 95,
#  'apportioned': 96,
#  'among': 97,
#  'may': 98,
#  'included': 99,
#  'within': 100,
#  'according': 101,
#  'their': 102,
#  'respective': 103,
#  'numbers': 104,
#  'determined': 105,
#  'adding': 106,
#  'whole': 107,
#  'number': 108,
#  'free': 109,
#  'persons': 110,
#  'including': 111,
#  'those': 112,
#  'bound': 113,
#  'service': 114,
#  'term': 115,
#  'excluding': 116,
#  'indians': 117,
#  'taxed': 118,
#  'three': 119,
#  'fifths': 120,
#  'other': 121,
#  'actual': 122,
#  'enumeration': 123,
#  'made': 124,
#  'after': 125,
#  'first': 126,
#  'meeting': 127,
#  'subsequent': 128,
#  'ten': 129,
#  'such': 130,
#  'manner': 131,
#  'as': 132,
#  'they': 133,
#  'law': 134,
#  'exceed': 135,
#  'one': 136,
#  'thirty': 137,
#  'thousand': 138,
#  'but': 139,
#  'at': 140,
#  'least': 141,
#  'until': 142,
#  'new': 143,
#  'hampshire': 144,
#  'entitled': 145,
#  'chuse': 146,
#  'massachusetts': 147,
#  'eight': 148,
#  'rhodeisland': 149,
#  'providence': 150,
#  'plantations': 151,
#  'connecticut': 152,
#  'newyork': 153,
#  'six': 154,
#  'jersey': 155,
#  'four': 156,
#  'pennsylvania': 157,
#  'delaware': 158,
#  'maryland': 159,
#  'virginia': 160,
#  'north': 161,
#  'carolina': 162,
#  'south': 163,
#  'georgia': 164,
#  'vacancies': 165,
#  'happen': 166,
#  'representation': 167,
#  'from': 168,
#  'any': 169,
#  'executive': 170,
#  'authority': 171,
#  'thereof': 172,
#  'issue': 173,
#  'writs': 174,
#  'election': 175,
#  'fill': 176,
#  'speaker': 177,
#  'officers': 178,
#  'sole': 179,
#  'power': 180,
#  'impeachment': 181,
#  '3': 182,
#  'two': 183,
#  'senators': 184,
#  'senator': 185,
#  'vote': 186,
#  'immediately': 187,
#  'assembled': 188,
#  'consequence': 189,
#  'divided': 190,
#  'equally': 191,
#  'into': 192,
#  'classes': 193,
#  'seats': 194,
#  'class': 195,
#  'vacated': 196,
#  'expiration': 197,
#  'fourth': 198,
#  'third': 199,
#  'sixth': 200,
#  'so': 201,
#  'if': 202,
#  'resignation': 203,
#  'or': 204,
#  'otherwise': 205,
#  'during': 206,
#  'recess': 207,
#  'make': 208,
#  'temporary': 209,
#  'appointments': 210,
#  'next': 211,
#  'then': 212,
#  'nine': 213,
#  'vice': 214,
#  'president': 215,
#  'unless': 216,
#  'also': 217,
#  'pro': 218,
#  'tempore': 219,
#  'absence': 220,
#  'exercise': 221,
#  'office': 222,
#  'try': 223,
#  'impeachments': 224,
#  'sitting': 225,
#  'purpose': 226,
#  'on': 227,
#  'oath': 228,
#  'affirmation': 229,
#  'is': 230,
#  'tried': 231,
#  'chief': 232,
#  'preside': 233,
#  'convicted': 234,
#  'without': 235,
#  'concurrence': 236,
#  'thirds': 237,
#  'present': 238,
#  'judgment': 239,
#  'cases': 240,
#  'extend': 241,
#  'further': 242,
#  'than': 243,
#  'removal': 244,
#  'disqualification': 245,
#  'hold': 246,
#  'enjoy': 247,
#  'honor': 248,
#  'trust': 249,
#  'profit': 250,
#  'under': 251,
#  'party': 252,
#  'nevertheless': 253,
#  'liable': 254,
#  'subject': 255,
#  'indictment': 256,
#  'trial': 257,
#  'punishment': 258,
#  '4': 259,
#  'times': 260,
#  'places': 261,
#  'holding': 262,
#  'elections': 263,
#  'prescribed': 264,
#  'time': 265,
#  'alter': 266,
#  'regulations': 267,
#  'except': 268,
#  'chusing': 269,
#  'assemble': 270,
#  'once': 271,
#  'monday': 272,
#  'december': 273,
#  'appoint': 274,
#  'different': 275,
#  'day': 276,
#  '5': 277,
#  'judge': 278,
#  'returns': 279,
#  'its': 280,
#  'own': 281,
#  'majority': 282,
#  'constitute': 283,
#  'quorum': 284,
#  'business': 285,
#  'smaller': 286,
#  'adjourn': 287,
#  'authorized': 288,
#  'compel': 289,
#  'attendance': 290,
#  'absent': 291,
#  'penalties': 292,
#  'determine': 293,
#  'rules': 294,
#  'proceedings': 295,
#  'punish': 296,
#  'disorderly': 297,
#  'behaviour': 298,
#  'with': 299,
#  'expel': 300,
#  'member': 301,
#  'keep': 302,
#  'journal': 303,
#  'publish': 304,
#  'same': 305,
#  'excepting': 306,
#  'parts': 307,
#  'require': 308,
#  'secrecy': 309,
#  'yeas': 310,
#  'nays': 311,
#  'either': 312,
#  'question': 313,
#  'desire': 314,
#  'fifth': 315,
#  'entered': 316,
#  'neither': 317,
#  'session': 318,
#  'consent': 319,
#  'days': 320,
#  'nor': 321,
#  'place': 322,
#  'houses': 323,
#  '6': 324,
#  'receive': 325,
#  'compensation': 326,
#  'services': 327,
#  'ascertained': 328,
#  'paid': 329,
#  'out': 330,
#  'treasury': 331,
#  'treason': 332,
#  'felony': 333,
#  'breach': 334,
#  'peace': 335,
#  'privileged': 336,
#  'arrest': 337,
#  'going': 338,
#  'returning': 339,
#  'speech': 340,
#  'debate': 341,
#  'questioned': 342,
#  'was': 343,
#  'appointed': 344,
#  'civil': 345,
#  'created': 346,
#  'emoluments': 347,
#  'whereof': 348,
#  'encreased': 349,
#  'his': 350,
#  'continuance': 351,
#  '7': 352,
#  'bills': 353,
#  'raising': 354,
#  'revenue': 355,
#  'originate': 356,
#  'propose': 357,
#  'concur': 358,
#  'amendments': 359,
#  'bill': 360,
#  'passed': 361,
#  'before': 362,
#  'it': 363,
#  'become': 364,
#  'presented': 365,
#  'approve': 366,
#  'sign': 367,
#  'return': 368,
#  'objections': 369,
#  'originated': 370,
#  'enter': 371,
#  'large': 372,
#  'proceed': 373,
#  'reconsider': 374,
#  'reconsideration': 375,
#  'agree': 376,
#  'pass': 377,
#  'sent': 378,
#  'together': 379,
#  'likewise': 380,
#  'reconsidered': 381,
#  'approved': 382,
#  'votes': 383,
#  'both': 384,
#  'names': 385,
#  'voting': 386,
#  'against': 387,
#  'respectively': 388,
#  'returned': 389,
#  'sundays': 390,
#  'excepted': 391,
#  'him': 392,
#  'like': 393,
#  'had': 394,
#  'signed': 395,
#  'adjournment': 396,
#  'prevent': 397,
#  'case': 398,
#  'resolution': 399,
#  'necessary': 400,
#  'take': 401,
#  'effect': 402,
#  'being': 403,
#  'disapproved': 404,
#  'repassed': 405,
#  'limitations': 406,
#  '8': 407,
#  'lay': 408,
#  'collect': 409,
#  'duties': 410,
#  'imposts': 411,
#  'excises': 412,
#  'pay': 413,
#  'debts': 414,
#  'uniform': 415,
#  'throughout': 416,
#  'borrow': 417,
#  'money': 418,
#  'credit': 419,
#  'regulate': 420,
#  'commerce': 421,
#  'foreign': 422,
#  'nations': 423,
#  'indian': 424,
#  'tribes': 425,
#  'rule': 426,
#  'naturalization': 427,
#  'laws': 428,
#  'bankruptcies': 429,
#  'coin': 430,
#  'value': 431,
#  'fix': 432,
#  'standard': 433,
#  'weights': 434,
#  'measures': 435,
#  'counterfeiting': 436,
#  'securities': 437,
#  'current': 438,
#  'post': 439,
#  'offices': 440,
#  'roads': 441,
#  'progress': 442,
#  'science': 443,
#  'useful': 444,
#  'arts': 445,
#  'securing': 446,
#  'limited': 447,
#  'authors': 448,
#  'inventors': 449,
#  'exclusive': 450,
#  'right': 451,
#  'writings': 452,
#  'discoveries': 453,
#  'tribunals': 454,
#  'inferior': 455,
#  'supreme': 456,
#  'court': 457,
#  'define': 458,
#  'piracies': 459,
#  'felonies': 460,
#  'committed': 461,
#  'high': 462,
#  'seas': 463,
#  'offences': 464,
#  'declare': 465,
#  'war': 466,
#  'grant': 467,
#  'letters': 468,
#  'marque': 469,
#  'reprisal': 470,
#  'concerning': 471,
#  'captures': 472,
#  'land': 473,
#  'water': 474,
#  'raise': 475,
#  'support': 476,
#  'armies': 477,
#  'appropriation': 478,
#  'use': 479,
#  'longer': 480,
#  'maintain': 481,
#  'navy': 482,
#  'government': 483,
#  'regulation': 484,
#  'naval': 485,
#  'forces': 486,
#  'calling': 487,
#  'forth': 488,
#  'militia': 489,
#  'execute': 490,
#  'suppress': 491,
#  'insurrections': 492,
#  'repel': 493,
#  'invasions': 494,
#  'organizing': 495,
#  'arming': 496,
#  'disciplining': 497,
#  'governing': 498,
#  'part': 499,
#  'them': 500,
#  'employed': 501,
#  'reserving': 502,
#  'appointment': 503,
#  'training': 504,
#  'discipline': 505,
#  'legislation': 506,
#  'whatsoever': 507,
#  'over': 508,
#  'district': 509,
#  'exceeding': 510,
#  'miles': 511,
#  'square': 512,
#  'cession': 513,
#  'particular': 514,
#  'acceptance': 515,
#  'seat': 516,
#  'purchased': 517,
#  'erection': 518,
#  'forts': 519,
#  'magazines': 520,
#  'arsenals': 521,
#  'dockyards': 522,
#  'needful': 523,
#  'buildingsand': 524,
#  'proper': 525,
#  'carrying': 526,
#  'execution': 527,
#  'foregoing': 528,
#  'department': 529,
#  'officer': 530,
#  '9': 531,
#  'migration': 532,
#  'importation': 533,
#  'now': 534,
#  'existing': 535,
#  'think': 536,
#  'admit': 537,
#  'prohibited': 538,
#  'prior': 539,
#  'hundred': 540,
#  'tax': 541,
#  'duty': 542,
#  'imposed': 543,
#  'dollars': 544,
#  'privilege': 545,
#  'writ': 546,
#  'habeas': 547,
#  'corpus': 548,
#  'suspended': 549,
#  'rebellion': 550,
#  'invasion': 551,
#  'public': 552,
#  'safety': 553,
#  'attainder': 554,
#  'ex': 555,
#  'facto': 556,
#  'capitation': 557,
#  'laid': 558,
#  'proportion': 559,
#  'census': 560,
#  'directed': 561,
#  'taken': 562,
#  'articles': 563,
#  'exported': 564,
#  'preference': 565,
#  'given': 566,
#  'ports': 567,
#  'another': 568,
#  'vessels': 569,
#  'obliged': 570,
#  'clear': 571,
#  'drawn': 572,
#  'appropriations': 573,
#  'regular': 574,
#  'statement': 575,
#  'account': 576,
#  'receipts': 577,
#  'expenditures': 578,
#  'published': 579,
#  'title': 580,
#  'nobility': 581,
#  'accept': 582,
#  'emolument': 583,
#  'kind': 584,
#  'whatever': 585,
#  'king': 586,
#  'prince': 587,
#  '10': 588,
#  'treaty': 589,
#  'alliance': 590,
#  'confederation': 591,
#  'emit': 592,
#  'thing': 593,
#  'gold': 594,
#  'silver': 595,
#  'tender': 596,
#  'payment': 597,
#  'impairing': 598,
#  'obligation': 599,
#  'contracts': 600,
#  'imports': 601,
#  'exports': 602,
#  'what': 603,
#  'absolutely': 604,
#  'executing': 605,
#  'inspection': 606,
#  'net': 607,
#  'produce': 608,
#  'revision': 609,
#  'controul': 610,
#  'tonnage': 611,
#  'troops': 612,
#  'ships': 613,
#  'agreement': 614,
#  'compact': 615,
#  'engage': 616,
#  'actually': 617,
#  'invaded': 618,
#  'imminent': 619,
#  'danger': 620,
#  'will': 621,
#  'delay': 622,
#  'ii': 623,
#  'follows': 624,
#  'equal': 625,
#  'elector': 626,
#  'meet': 627,
#  'ballot': 628,
#  'whom': 629,
#  'themselves': 630,
#  'list': 631,
#  'voted': 632,
#  'certify': 633,
#  'transmit': 634,
#  'sealed': 635,
#  'presence': 636,
#  'open': 637,
#  'certificates': 638,
#  'counted': 639,
#  'having': 640,
#  'greatest': 641,
#  'there': 642,
#  'highest': 643,
#  'said': 644,
#  'choice': 645,
#  'should': 646,
#  'remain': 647,
#  'give': 648,
#  'natural': 649,
#  'born': 650,
#  'adoption': 651,
#  'eligible': 652,
#  'fourteen': 653,
#  'resident': 654,
#  'death': 655,
#  'inability': 656,
#  'discharge': 657,
#  'devolve': 658,
#  'declaring': 659,
#  'act': 660,
#  'accordingly': 661,
#  'disability': 662,
#  'removed': 663,
#  'stated': 664,
#  'increased': 665,
#  'diminished': 666,
#  'period': 667,
#  'following': 668,
#  'affirmationi': 669,
#  'solemnly': 670,
#  'swear': 671,
#  'affirm': 672,
#  'faithfully': 673,
#  'best': 674,
#  'my': 675,
#  'ability': 676,
#  'preserve': 677,
#  'protect': 678,
#  'defend': 679,
#  'commander': 680,
#  'army': 681,
#  'called': 682,
#  'opinion': 683,
#  'writing': 684,
#  'principal': 685,
#  'departments': 686,
#  'upon': 687,
#  'relating': 688,
#  'reprieves': 689,
#  'pardons': 690,
#  'advice': 691,
#  'treaties': 692,
#  'provided': 693,
#  'nominate': 694,
#  'ambassadors': 695,
#  'ministers': 696,
#  'consuls': 697,
#  'judges': 698,
#  'whose': 699,
#  'are': 700,
#  'established': 701,
#  'vest': 702,
#  'alone': 703,
#  'courts': 704,
#  'heads': 705,
#  'up': 706,
#  'granting': 707,
#  'commissions': 708,
#  'expire': 709,
#  'end': 710,
#  'information': 711,
#  'recommend': 712,
#  'consideration': 713,
#  'expedient': 714,
#  'extraordinary': 715,
#  'occasions': 716,
#  'convene': 717,
#  'disagreement': 718,
#  'between': 719,
#  'respect': 720,
#  'care': 721,
#  'executed': 722,
#  'commission': 723,
#  'conviction': 724,
#  'bribery': 725,
#  'crimes': 726,
#  'misdemeanors': 727,
#  'iii': 728,
#  'judicial': 729,
#  'good': 730,
#  'equity': 731,
#  'arising': 732,
#  'authorityto': 733,
#  'affecting': 734,
#  'consulsto': 735,
#  'admiralty': 736,
#  'maritime': 737,
#  'jurisdictionto': 738,
#  'controversies': 739,
#  'partyto': 740,
#  'citizens': 741,
#  'statebetween': 742,
#  'statesbetween': 743,
#  'claiming': 744,
#  'lands': 745,
#  'grants': 746,
#  'subjects': 747,
#  'original': 748,
#  'jurisdiction': 749,
#  'mentioned': 750,
#  'appellate': 751,
#  'fact': 752,
#  'exceptions': 753,
#  'jury': 754,
#  'held': 755,
#  'where': 756,
#  'only': 757,
#  'levying': 758,
#  'adhering': 759,
#  'enemies': 760,
#  'giving': 761,
#  'aid': 762,
#  'comfort': 763,
#  'testimony': 764,
#  'witnesses': 765,
#  'overt': 766,
#  'confession': 767,
#  'work': 768,
#  'corruption': 769,
#  'blood': 770,
#  'forfeiture': 771,
#  'life': 772,
#  'attainted': 773,
#  'iv': 774,
#  'full': 775,
#  'faith': 776,
#  'acts': 777,
#  'records': 778,
#  'prescribe': 779,
#  'proved': 780,
#  'privileges': 781,
#  'immunities': 782,
#  'charged': 783,
#  'crime': 784,
#  'flee': 785,
#  'found': 786,
#  'demand': 787,
#  'fled': 788,
#  'delivered': 789,
#  'labour': 790,
#  'escaping': 791,
#  'therein': 792,
#  'discharged': 793,
#  'claim': 794,
#  'due': 795,
#  'admitted': 796,
#  'formed': 797,
#  'erected': 798,
#  'junction': 799,
#  'legislatures': 800,
#  'concerned': 801,
#  'well': 802,
#  'dispose': 803,
#  'respecting': 804,
#  'territory': 805,
#  'property': 806,
#  'belonging': 807,
#  'nothing': 808,
#  'construed': 809,
#  'prejudice': 810,
#  'claims': 811,
#  'guarantee': 812,
#  'republican': 813,
#  'application': 814,
#  'cannot': 815,
#  'convened': 816,
#  'violence': 817,
#  'v': 818,
#  'whenever': 819,
#  'deem': 820,
#  'call': 821,
#  'convention': 822,
#  'proposing': 823,
#  'valid': 824,
#  'intents': 825,
#  'purposes': 826,
#  'ratified': 827,
#  'fourths': 828,
#  'conventions': 829,
#  'mode': 830,
#  'ratification': 831,
#  'proposed': 832,
#  'amendment': 833,
#  'affect': 834,
#  'clauses': 835,
#  'ninth': 836,
#  'deprived': 837,
#  'suffrage': 838,
#  'vi': 839,
#  'contracted': 840,
#  'engagements': 841,
#  'pursuance': 842,
#  'thereby': 843,
#  'contrary': 844,
#  'notwithstanding': 845,
#  'religious': 846,
#  'test': 847,
#  'ever': 848,
#  'required': 849,
#  'qualification': 850,
#  'vii': 851,
#  'sufficient': 852,
#  'establishment': 853,
#  'ratifying': 854,
#  'word': 855,
#  'interlined': 856,
#  'seventh': 857,
#  'eighth': 858,
#  'lines': 859,
#  'page': 860,
#  'partly': 861,
#  'written': 862,
#  'erazure': 863,
#  'fifteenth': 864,
#  'line': 865,
#  'words': 866,
#  'forty': 867,
#  'attest': 868,
#  'william': 869,
#  'jackson': 870,
#  'secretary': 871,
#  'done': 872,
#  'unanimous': 873,
#  'seventeenth': 874,
#  'september': 875,
#  'lord': 876,
#  'eighty': 877,
#  'independance': 878,
#  'twelfth': 879,
#  'witness': 880,
#  'hereunto': 881,
#  'subscribed': 882}

# %% [markdown]
# ## Part G: Visualization of the sparsities of A and O

# %% [markdown]
# We can visualize the sparsities of the A and O matrices by treating the matrix entries as intensity values and showing them as images. What patterns do you notice?

# %%
visualize_sparsities(hmm8, O_max_cols=50)

# %% [markdown]
# ## Generating a sample sentence

# %% [markdown]
# As you have already seen, an HMM can be used to generate sample sequences based on the given dataset. Run the cell below to show a sample sentence based on the Constitution.

# %%
print('Sample Sentence:\n====================')
print(sample_sentence(hmm8, obs_map, n_words=25))
# Out:
# Sample Sentence:
# ====================
# Office prior land cases jackson three supreme offences ten thirty naturalization congress facto be time affirmationi useful time they the places into states debts of...

# %% [markdown]
# ## Part H: Using varying numbers of hidden states

# %% [markdown]
# Using different numbers of hidden states can lead to different behaviours in the HMMs. Below, we train several HMMs with 1, 2, 4, and 16 hidden states, respectively. What do you notice about their emissions? How do these emissions compare to the emission above?

# %%
hmm1 = unsupervised_HMM(obs, 1, 100)
print('\nSample Sentence:\n====================')
print(sample_sentence(hmm1, obs_map, n_words=25))
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
#
# Sample Sentence:
# ====================
# Constitution the yeas any cases of of and the in first attainted one and of the places imposts of between directed citizens respective such shall...

# %%
hmm2 = unsupervised_HMM(obs, 2, 100)
print('\nSample Sentence:\n====================')
print(sample_sentence(hmm2, obs_map, n_words=25))
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
#
# Sample Sentence:
# ====================
# Money shall by or writs manner when time he and who employed by shall another power provide william such treason senate the measures removal them...

# %%
hmm4 = unsupervised_HMM(obs, 4, 100)
print('\nSample Sentence:\n====================')
print(sample_sentence(hmm4, obs_map, n_words=25))
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
#
# Sample Sentence:
# ====================
# Discipline and the places felonies united state i the years in treason and impeachment impeachment consideration powers shall the two states and other section adjourn...

# %%
hmm16 = unsupervised_HMM(obs, 16, 100)
print('\nSample Sentence:\n====================')
print(sample_sentence(hmm16, obs_map, n_words=25))
# Out:
# Iteration: 10
# Iteration: 20
# Iteration: 30
# Iteration: 40
# Iteration: 50
# Iteration: 60
# Iteration: 70
# Iteration: 80
# Iteration: 90
# Iteration: 100
#
# Sample Sentence:
# ====================
# To such and all the needful election any section be convicted but he shall be act all credit declaring be proportion up of they shall...

# %% [markdown]
# ## Part I: Visualizing the wordcloud of each state

# %% [markdown]
# Below, we visualize each state as a wordcloud by sampling a large emission from the state:

# %%
wordclouds = states_to_wordclouds(hmm8, obs_map)

# %% [markdown]
# ## Visualizing the process of an HMM generating an emission

# %% [markdown]
# The visualization below shows how an HMM generates an emission. Each state is shown as a wordcloud on the plot, and transition probabilities between the states are shown as arrows. The darker an arrow, the higher the transition probability.
#
# At every frame, a transition is taken and an observation is emitted from the new state. A red arrow indicates that the transition was just taken. If a transition stays at the same state, it is represented as an arrowhead on top of that state.
#
# Use fullscreen for a better view of the process.

# %%
anim = animate_emission(hmm8, obs_map, M=8)
HTML(anim.to_html5_video())
# Out:
# Animating...
# <video width="864" height="864" controls autoplay loop>
#   <source type="video/mp4" src="...
