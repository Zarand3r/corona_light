# %%
import pandas as pd
import numpy as np
import os

# %%
#Loading in County Data
Age_Race = pd.read_csv('../../../data/us/demographics/acs_2018.csv', encoding='latin1')
County_Pop_Pop60 = pd.read_csv('../../../data/us/demographics/county_populations.csv', encoding='latin1')
Area_Houses = pd.read_csv('../../../data/us/demographics/county_land_areas.csv', encoding='latin1')
Educ = pd.read_csv('../../../data/us/demographics/education.csv', encoding='latin1')
Unemp = pd.read_csv('../../../data/us/demographics/unemployment.csv', delimiter="\t")
Poverty = pd.read_csv('../../../data/us/demographics/poverty.csv', delimiter="\t")
Votes = pd.read_csv('../../../data/us/demographics/countypres_2000-2016.csv', encoding='latin1')

#State Populations
State_Pop = pd.read_csv('../../../data/us/demographics/state_populations.csv', encoding='latin1')

# %%
#Changes prefixes of column names
def drop_prefix(self, prefix, replace = ''):
    self.columns = self.columns.str.replace(prefix, replace)
    return self

# %%
#Cleaning Voting Data
Votes = Votes[Votes.party != 'green']
Votes = Votes[Votes.party != 'republican'] #Removing unneeded rows
Votes = Votes[Votes.candidate != 'Other']
Votes = Votes[Votes.FIPS <= 10000000]

Votes = Votes.drop(columns=['state', 'state_po', 'county', 'office', 'candidate', 'version']) #removing uneeded columns

Votes.insert(5, "Prop_Blue", Votes.candidatevotes/Votes.totalvotes, True) #Adding column of proportion of democratic
Votes = Votes.drop(columns=['candidatevotes', 'party'])    
Votes = Votes.pivot(index= 'FIPS', columns = 'year') #making FIPS main index
Votes.to_csv('Votes.csv')

# %%
#Cleaning the Racial/Age Data
Age_Race.sort_values(by=['FIPS'])
Age_Race = Age_Race[Age_Race.columns.drop(list(Age_Race.filter(regex='Percent')))]
Age_Race = Age_Race[Age_Race.columns.drop(list(Age_Race.filter(regex='ratio')))]
#Dropping unecessary columns
Age_Race = drop_prefix(Age_Race, 'Estimate!!')
Age_Race = drop_prefix(Age_Race, 'SEX AND AGE!!')
Age_Race = drop_prefix(Age_Race, 'RACE!!')
Age_Race = drop_prefix(Age_Race, 'Total population!!') #Changing column title names
Age_Race = drop_prefix(Age_Race, 'One race!!', 'Race_1 ')
Age_Race = drop_prefix(Age_Race, 'Two or more races!!', 'Race_2+ ')
Age_Race = drop_prefix(Age_Race, 'Race alone or in combination with one or more other races!!', 'Race_Total ')
Age_Race = drop_prefix(Age_Race, 'Race alone or in combination with one or more other races!!', 'Race_Total ')
Age_Race = drop_prefix(Age_Race, 'HISPANIC OR LATINO AND', 'Hispanic:')
Age_Race.to_csv('Age_Race.csv')

# %%
#Joining Population and Unemployment Data
Pop_Unemp =  pd.merge(County_Pop_Pop60, Unemp, left_on='FIPS', right_on='FIPS')
#Joining this with Land Area/Density Data
Pop_Unemp_Area = pd.merge(Pop_Unemp, Area_Houses, left_on='FIPS', right_on='County FIPS')
Pop_Unemp_Area = Pop_Unemp_Area.drop(columns=['County FIPS', 'Area in square miles - Total area', 'County Name'])
#Joining this with Education Data
Pop_Unemp_Area_Educ = pd.merge(Pop_Unemp_Area, Educ, left_on='FIPS', right_on='FIPS')
#Joining this with Poverty Data
Pop_Unemp_Area_Educ_Pov = pd.merge(Pop_Unemp_Area_Educ, Poverty, left_on='FIPS', right_on='FIPS')
#Joining this with Voting Data
Pop_Unemp_Area_Educ_Pov_Votes = pd.merge(Pop_Unemp_Area_Educ_Pov, Votes, left_on='FIPS', right_on='FIPS')


#Joining Compiled Data with Racial/Age Data (This is incomplete, not all FIPS included)
Demographics_Full = pd.merge(Pop_Unemp_Area_Educ, Age_Race, left_on='FIPS', right_on='FIPS')
# Out:
# C:\Users\jethi\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py:522: UserWarning: merging between different levels can give an unintended result (1 levels on the left, 2 on the right)
#   warnings.warn(msg, UserWarning)

# %%
print('County_Pop_Pop60: ' + str(len(County_Pop_Pop60)))
print('Area_Houses: ' + str(len(Area_Houses)))
print('Educ: ' + str(len(Educ)))
print('Unemp: ' + str(len(Unemp)))
print('Poverty: ' + str(len(Poverty)))
print('Votes: ' + str(len(Votes)) + '\n')

print('Age_Race: ' + str(len(Age_Race)) + '\n')

print('Pop_Unemp: ' + str(len(Pop_Unemp)))
print('Pop_Unemp_Area: ' + str(len(Pop_Unemp_Area)))
print('Pop_Unemp_Area_Educ: ' + str(len(Pop_Unemp_Area_Educ)))
print('Pop_Unemp_Area_Educ_Pov: ' + str(len(Pop_Unemp_Area_Educ_Pov)))
print('Pop_Unemp_Area_Educ_Pov_Votes: ' + str(len(Pop_Unemp_Area_Educ_Pov_Votes)) + '\n')

print('Demographics_Full: ' + str(len(Demographics_Full)))
# Out:
# County_Pop_Pop60: 3142
# Area_Houses: 3221
# Educ: 3283
# Unemp: 3141
# Poverty: 3136
# Votes: 3155
#
# Age_Race: 838
#
# Pop_Unemp: 3141
# Pop_Unemp_Area: 3139
# Pop_Unemp_Area_Educ: 3139
# Pop_Unemp_Area_Educ_Pov: 3134
# Pop_Unemp_Area_Educ_Pov_Votes: 3114
#
# Demographics_Full: 827

# %%
pd.set_option('max_columns', None)
Pop_Unemp_Area_Educ_Pov_Votes.head()
# Out:
#    FIPS  total_pop  60plus State         Area_name_x  \
# 0  1001      55036   10523    AL  Autauga County, AL
# 1  1003     203360   53519    AL  Baldwin County, AL
# 2  1005      26201    6150    AL  Barbour County, AL
# 3  1007      22580    4773    AL     Bibb County, AL
# 4  1009      57667   13600    AL   Blount County, AL
#
#    Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 0                                2                          2           1
# 1                                3                          2           1
# 2                                6                          6           0
# 3                                1                          1           1
# 4                                1                          1           1
#
#   Civilian_labor_force_2018 Employed_2018 Unemployed_2018  \
# 0                    25,957        25,015             942
# 1                    93,849        90,456           3,393
# 2                     8,373         7,940             433
# 3                     8,661         8,317             344
# 4                    25,006        24,128             878
#
#    Unemployment_rate_2018 Median_Household_Income_2018  \
# 0                     3.6                     $59,338
# 1                     3.6                     $57,588
# 2                     5.2                     $34,382
# 3                     4.0                     $46,064
# 4                     3.5                     $50,412
#
#    Med_HH_Income_Percent_of_State_Total_2018  \
# 0                                      119.0
# 1                                      115.5
# 2                                       68.9
# 3                                       92.3
# 4                                      101.1
#
#    Area in square miles - Land area  \
# 0                            594.44
# 1                           1589.78
# 2                            884.88
# 3                            622.58
# 4                            644.78
#
#    2010 Density per square mile of land area - Population  \
# 0                                               91.8
# 1                                              114.6
# 2                                               31.0
# 3                                               36.8
# 4                                               88.9
#
#    2010 Density per square mile of land area - Housing units  \
# 0                                               37.2
# 1                                               65.5
# 2                                               13.4
# 3                                               14.4
# 4                                               37.0
#
#   Less than a high school diploma, 2014-18 High school diploma only, 2014-18  \
# 0                                    4,204                            12,119
# 1                                   14,310                            40,579
# 2                                    4,901                             6,486
# 3                                    2,650                             7,471
# 4                                    7,861                            13,489
#
#   Some college or associate's degree, 2014-18  \
# 0                                      10,552
# 1                                      46,025
# 2                                       4,566
# 3                                       3,846
# 4                                      13,267
#
#   Bachelor's degree or higher, 2014-18  \
# 0                               10,291
# 1                               46,075
# 2                                2,220
# 3                                1,813
# 4                                5,010
#
#    Percent of adults with less than a high school diploma, 2014-18  \
# 0                                               11.3
# 1                                                9.7
# 2                                               27.0
# 3                                               16.8
# 4                                               19.8
#
#    Percent of adults with a high school diploma only, 2014-18  \
# 0                                               32.6
# 1                                               27.6
# 2                                               35.7
# 3                                               47.3
# 4                                               34.0
#
#    Percent of adults completing some college or associate's degree, 2014-18  \
# 0                                               28.4
# 1                                               31.3
# 2                                               25.1
# 3                                               24.4
# 4                                               33.5
#
#    Percent of adults with a bachelor's degree or higher, 2014-18 Stabr  \
# 0                                               27.7                AL
# 1                                               31.3                AL
# 2                                               12.2                AL
# 3                                               11.5                AL
# 4                                               12.6                AL
#
#       Area_name_y  Rural-urban_Continuum_Code_2003  Urban_Influence_Code_2003  \
# 0  Autauga County                                2                          2
# 1  Baldwin County                                4                          5
# 2  Barbour County                                6                          6
# 3     Bibb County                                1                          1
# 4   Blount County                                1                          1
#
#    Rural-urban_Continuum_Code_2013  Urban_Influence_Code_2013 POVALL_2018  \
# 0                                2                          2       7,587
# 1                                3                          2      21,069
# 2                                6                          6       6,788
# 3                                1                          1       4,400
# 4                                1                          1       7,527
#
#   CI90LBAll_2018 CI90UBALL_2018  PCTPOVALL_2018  CI90LBALLP_2018  \
# 0          6,334          8,840            13.8             11.5
# 1         17,390         24,748             9.8              8.1
# 2          5,662          7,914            30.9             25.8
# 3          3,445          5,355            21.8             17.1
# 4          6,045          9,009            13.2             10.6
#
#    CI90UBALLP_2018 POV017_2018 CI90LB017_2018 CI90UB017_2018  PCTPOV017_2018  \
# 0             16.1       2,509          1,965          3,053            19.3
# 1             11.5       6,442          4,723          8,161            13.9
# 2             36.0       2,242          1,788          2,696            43.9
# 3             26.5       1,238            923          1,553            27.8
# 4             15.8       2,374          1,784          2,964            18.0
#
#    CI90LB017P_2018  CI90UB017P_2018 POV517_2018 CI90LB517_2018 CI90UB517_2018  \
# 0             15.1             23.5       1,891          1,469          2,313
# 1             10.2             17.6       4,534          3,223          5,845
# 2             35.0             52.8       1,411          1,056          1,766
# 3             20.7             34.9         840            606          1,074
# 4             13.5             22.5       1,520          1,053          1,987
#
#    PCTPOV517_2018  CI90LB517P_2018  CI90UB517P_2018 MEDHHINC_2018  \
# 0            19.5             15.1             23.9        59,338
# 1            13.1              9.3             16.9        57,588
# 2            36.7             27.5             45.9        34,382
# 3            26.3             19.0             33.6        46,064
# 4            15.5             10.7             20.3        50,412
#
#   CI90LBINC_2018 CI90UBINC_2018  (totalvotes, 2000)  (totalvotes, 2004)  \
# 0         53,628         65,048             17208.0             20081.0
# 1         54,437         60,739             56480.0             69320.0
# 2         31,157         37,607             10395.0             10777.0
# 3         41,283         50,845              7101.0              7600.0
# 4         46,157         54,667             17973.0             21504.0
#
#    (totalvotes, 2008)  (totalvotes, 2012)  (totalvotes, 2016)  \
# 0             23641.0             23932.0             24973.0
# 1             81413.0             85338.0             95215.0
# 2             11630.0             11509.0             10469.0
# 3              8644.0              8420.0              8819.0
# 4             24267.0             24006.0             25588.0
#
#    (Prop_Blue, 2000)  (Prop_Blue, 2004)  (Prop_Blue, 2008)  (Prop_Blue, 2012)  \
# 0           0.287192           0.236940           0.257730           0.265878
# 1           0.247822           0.225029           0.238119           0.215894
# 2           0.499086           0.448362           0.489854           0.513685
# 3           0.381636           0.274868           0.265965           0.261520
# 4           0.276915           0.183129           0.145135           0.123719
#
#    (Prop_Blue, 2016)
# 0           0.237697
# 1           0.193856
# 2           0.465278
# 3           0.212496
# 4           0.084258

# %%
list(Pop_Unemp_Area_Educ_Pov_Votes.columns)
# Out:
# ['FIPS',
#  'total_pop',
#  '60plus',
#  'State',
#  'Area_name_x',
#  'Rural_urban_continuum_code_2013',
#  'Urban_influence_code_2013',
#  'Metro_2013',
#  'Civilian_labor_force_2018',
#  'Employed_2018',
#  'Unemployed_2018',
#  'Unemployment_rate_2018',
#  'Median_Household_Income_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Area in square miles - Land area',
#  '2010 Density per square mile of land area - Population',
#  '2010 Density per square mile of land area - Housing units',
#  'Less than a high school diploma, 2014-18',
#  'High school diploma only, 2014-18',
#  "Some college or associate's degree, 2014-18",
#  "Bachelor's degree or higher, 2014-18",
#  'Percent of adults with less than a high school diploma, 2014-18',
#  'Percent of adults with a high school diploma only, 2014-18',
#  "Percent of adults completing some college or associate's degree, 2014-18",
#  "Percent of adults with a bachelor's degree or higher, 2014-18",
#  'Stabr',
#  'Area_name_y',
#  'Rural-urban_Continuum_Code_2003',
#  'Urban_Influence_Code_2003',
#  'Rural-urban_Continuum_Code_2013',
#  'Urban_Influence_Code_2013',
#  'POVALL_2018',
#  'CI90LBAll_2018',
#  'CI90UBALL_2018',
#  'PCTPOVALL_2018',
#  'CI90LBALLP_2018',
#  'CI90UBALLP_2018',
#  'POV017_2018',
#  'CI90LB017_2018',
#  'CI90UB017_2018',
#  'PCTPOV017_2018',
#  'CI90LB017P_2018',
#  'CI90UB017P_2018',
#  'POV517_2018',
#  'CI90LB517_2018',
#  'CI90UB517_2018',
#  'PCTPOV517_2018',
#  'CI90LB517P_2018',
#  'CI90UB517P_2018',
#  'MEDHHINC_2018',
#  'CI90LBINC_2018',
#  'CI90UBINC_2018',
#  ('totalvotes', 2000),
#  ('totalvotes', 2004),
#  ('totalvotes', 2008),
#  ('totalvotes', 2012),
#  ('totalvotes', 2016),
#  ('Prop_Blue', 2000),
#  ('Prop_Blue', 2004),
#  ('Prop_Blue', 2008),
#  ('Prop_Blue', 2012),
#  ('Prop_Blue', 2016)]

# %%
Demographics_Full.head()
# Out:
#    FIPS  total_pop  60plus State           Area_name  \
# 0  1003     203360   53519    AL  Baldwin County, AL
# 1  1015     115527   27115    AL  Calhoun County, AL
# 2  1043      81703   19667    AL  Cullman County, AL
# 3  1049      71194   15782    AL   DeKalb County, AL
# 4  1051      80989   15929    AL   Elmore County, AL
#
#    Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 0                                3                          2           1
# 1                                3                          2           1
# 2                                4                          3           0
# 3                                6                          6           0
# 4                                2                          2           1
#
#   Civilian_labor_force_2018 Employed_2018 Unemployed_2018  \
# 0                    93,849        90,456           3,393
# 1                    45,972        43,833           2,139
# 2                    37,830        36,589           1,241
# 3                    30,129        28,979           1,150
# 4                    37,215        35,932           1,283
#
#    Unemployment_rate_2018 Median_Household_Income_2018  \
# 0                     3.6                     $57,588
# 1                     4.7                     $45,400
# 2                     3.3                     $45,796
# 3                     3.8                     $39,491
# 4                     3.4                     $60,367
#
#    Med_HH_Income_Percent_of_State_Total_2018  \
# 0                                      115.5
# 1                                       91.0
# 2                                       91.8
# 3                                       79.2
# 4                                      121.0
#
#    Area in square miles - Land area  \
# 0                           1589.78
# 1                            605.87
# 2                            734.84
# 3                            777.09
# 4                            618.48
#
#    2010 Density per square mile of land area - Population  \
# 0                                              114.6
# 1                                              195.7
# 2                                              109.4
# 3                                               91.5
# 4                                              128.2
#
#    2010 Density per square mile of land area - Housing units  \
# 0                                               65.5
# 1                                               88.0
# 2                                               50.4
# 3                                               40.0
# 4                                               52.8
#
#   Less than a high school diploma, 2014-18 High school diploma only, 2014-18  \
# 0                                   14,310                            40,579
# 1                                   12,620                            25,653
# 2                                   10,405                            20,382
# 3                                   12,394                            15,956
# 4                                    7,594                            18,304
#
#   Some college or associate's degree, 2014-18  \
# 0                                      46,025
# 1                                      26,643
# 2                                      18,559
# 3                                      13,441
# 4                                      16,197
#
#   Bachelor's degree or higher, 2014-18  \
# 0                               46,075
# 1                               14,219
# 2                                7,866
# 3                                6,085
# 4                               13,664
#
#    Percent of adults with less than a high school diploma, 2014-18  \
# 0                                                9.7
# 1                                               15.9
# 2                                               18.2
# 3                                               25.9
# 4                                               13.6
#
#    Percent of adults with a high school diploma only, 2014-18  \
# 0                                               27.6
# 1                                               32.4
# 2                                               35.6
# 3                                               33.3
# 4                                               32.8
#
#    Percent of adults completing some college or associate's degree, 2014-18  \
# 0                                               31.3
# 1                                               33.7
# 2                                               32.4
# 3                                               28.1
# 4                                               29.0
#
#    Percent of adults with a bachelor's degree or higher, 2014-18  \
# 0                                               31.3
# 1                                               18.0
# 2                                               13.7
# 3                                               12.7
# 4                                               24.5
#
#       Geographic Area Name  Total population    Male  Female  Under 5 years  \
# 0  Baldwin County, Alabama            218022  105437  112585          10878
# 1  Calhoun County, Alabama            114277   55054   59223           7142
# 2  Cullman County, Alabama             83442   40794   42648           5329
# 3   DeKalb County, Alabama             71385   35048   36337           3989
# 4   Elmore County, Alabama             81887   39988   41899           5246
#
#    5 to 9 years  10 to 14 years  15 to 19 years  20 to 24 years  \
# 0          9445           18093           13489           10426
# 1          7158            5968            7386            7451
# 2          4798            5226            5270            4500
# 3          3851            6121            5079            4176
# 4          4443            5024            5534            4847
#
#    25 to 34 years  35 to 44 years  45 to 54 years  55 to 59 years  \
# 0           23498           25990           30117           16569
# 1           16273           12608           13616            8305
# 2           10274           10131           10843            5407
# 3            8645            8261            9548            4533
# 4           12140           10087           11642            5364
#
#    60 to 64 years  65 to 74 years  75 to 84 years  85 years and over  \
# 0           15074           27152           13464               3827
# 1            7855           12240            6514               1761
# 2            6123            9116            5570                855
# 3            4921            7377            3342               1542
# 4            5261            7550            3764                985
#
#    Median age (years)  Under 18 years  16 years and over  18 years and over  \
# 0                44.0           47156             176222             170866
# 1                40.1           24484              93284              89793
# 2                40.6           18892              66680              64550
# 3                39.5           17145              57239              54240
# 4                38.4           18562              65407              63325
#
#    21 years and over  62 years and over  65 years and over  \
# 0             163886              53676              44443
# 1              84973              24963              20515
# 2              61088              18429              15541
# 3              51984              15204              12261
# 4              61214              15329              12299
#
#    18 years and over.1  18 years and over!!Male  18 years and over!!Female  \
# 0               170866                    81046                      89820
# 1                89793                    42655                      47138
# 2                64550                    31490                      33060
# 3                54240                    26083                      28157
# 4                63325                    30034                      33291
#
#    65 years and over.1  65 years and over!!Male  65 years and over!!Female  \
# 0                44443                    20457                      23986
# 1                20515                     8619                      11896
# 2                15541                     7048                       8493
# 3                12261                     5423                       6838
# 4                12299                     5538                       6761
#
#    Total population One race Two or more races One race.1 Race_1 White  \
# 0            218022   214558              3464     214558       187759
# 1            114277   111498              2779     111498        85046
# 2             83442    81383              2059      81383        78643
# 3             71385    70116              1269      70116        60157
# 4             81887    79941              1946      79941        60622
#
#   Race_1 Black or African American  \
# 0                            20554
# 1                            24737
# 2                              906
# 3                             1335
# 4                            17113
#
#   Margin of Error!!Race_1 Black or African American  \
# 0                                               446
# 1                                               642
# 2                                               335
# 3                                               201
# 4                                              1682
#
#   Race_1 American Indian and Alaska Native  \
# 0                                     1276
# 1                                      107
# 2                                      301
# 3                                      868
# 4                                      345
#
#   Race_1 American Indian and Alaska Native!!Cherokee tribal grouping  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_1 American Indian and Alaska Native!!Chippewa tribal grouping  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_1 American Indian and Alaska Native!!Navajo tribal grouping  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_1 American Indian and Alaska Native!!Sioux tribal grouping  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_1 Asian Race_1 Asian!!Asian Indian Race_1 Asian!!Chinese  \
# 0         2338                          N                     N
# 1          426                          N                     N
# 2          166                          N                     N
# 3          173                          N                     N
# 4          522                          N                     N
#
#   Race_1 Asian!!Filipino Race_1 Asian!!Japanese Race_1 Asian!!Korean  \
# 0                      N                      N                    N
# 1                      N                      N                    N
# 2                      N                      N                    N
# 3                      N                      N                    N
# 4                      N                      N                    N
#
#   Race_1 Asian!!Vietnamese Race_1 Asian!!Other Asian  \
# 0                        N                         N
# 1                        N                         N
# 2                        N                         N
# 3                        N                         N
# 4                        N                         N
#
#   Race_1 Native Hawaiian and Other Pacific Islander  \
# 0                                                45
# 1                                                 0
# 2                                                 0
# 3                                                 0
# 4                                                 0
#
#   Race_1 Native Hawaiian and Other Pacific Islander!!Native Hawaiian  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_1 Native Hawaiian and Other Pacific Islander!!Guamanian or Chamorro  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_1 Native Hawaiian and Other Pacific Islander!!Samoan  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_1 Native Hawaiian and Other Pacific Islander!!Other Pacific Islander  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_1 Some other race Two or more races.1  \
# 0                   2586                3464
# 1                   1182                2779
# 2                   1367                2059
# 3                   7583                1269
# 4                   1339                1946
#
#   Race_2+ White and Black or African American  \
# 0                                         227
# 1                                         487
# 2                                           N
# 3                                           N
# 4                                           N
#
#   Race_2+ White and American Indian and Alaska Native Race_2+ White and Asian  \
# 0                                               2100                      739
# 1                                                304                      767
# 2                                                  N                        N
# 3                                                  N                        N
# 4                                                  N                        N
#
#   Race_2+ Black or African American and American Indian and Alaska Native  \
# 0                                                  0
# 1                                                 26
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#    Race_Total Total population  Race_Total White  \
# 0                       218022            191157
# 1                       114277             87105
# 2                        83442             80522
# 3                        71385             61426
# 4                        81887             62491
#
#   Race_Total Black or African American  \
# 0                                20781
# 1                                25595
# 2                                 1246
# 3                                 1348
# 4                                18388
#
#   Race_Total American Indian and Alaska Native Race_Total Asian  \
# 0                                         3442             3143
# 1                                          489             1594
# 2                                         1210              903
# 3                                         1722              588
# 4                                          838              707
#
#   Race_Total Native Hawaiian and Other Pacific Islander  \
# 0                                                  N
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Race_Total Some other race  Hispanic: Total population  \
# 0                       2798                      218022
# 1                       2024                      114277
# 2                       1702                       83442
# 3                       7583                       71385
# 4                       1395                       81887
#
#    Hispanic: Hispanic or Latino (of any race)  \
# 0                                       10132
# 1                                        4469
# 2                                        3699
# 3                                       10595
# 4                                        2467
#
#   Hispanic: Hispanic or Latino (of any race)!!Mexican  \
# 0                                               5148
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Hispanic: Hispanic or Latino (of any race)!!Puerto Rican  \
# 0                                               1543
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#   Hispanic: Hispanic or Latino (of any race)!!Cuban  \
# 0                                               321
# 1                                                 N
# 2                                                 N
# 3                                                 N
# 4                                                 N
#
#   Hispanic: Hispanic or Latino (of any race)!!Other Hispanic or Latino  \
# 0                                               3120
# 1                                                  N
# 2                                                  N
# 3                                                  N
# 4                                                  N
#
#    Hispanic: Not Hispanic or Latino  \
# 0                            207890
# 1                            109808
# 2                             79743
# 3                             60790
# 4                             79420
#
#   Hispanic: Not Hispanic or Latino!!White alone  \
# 0                                        180926
# 1                                         82308
# 2                                             N
# 3                                         57199
# 4                                         59771
#
#   Hispanic: Not Hispanic or Latino!!Black or African American alone  \
# 0                                              20328
# 1                                              24737
# 2                                                  N
# 3                                               1335
# 4                                              16836
#
#   Hispanic: Not Hispanic or Latino!!American Indian and Alaska Native alone  \
# 0                                               1209
# 1                                                107
# 2                                                  N
# 3                                                814
# 4                                                345
#
#   Hispanic: Not Hispanic or Latino!!Asian alone  \
# 0                                          2338
# 1                                           426
# 2                                             N
# 3                                           173
# 4                                           522
#
#   Hispanic: Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone  \
# 0                                                 45
# 1                                                  0
# 2                                                  N
# 3                                                  0
# 4                                                  0
#
#   Hispanic: Not Hispanic or Latino!!Some other race alone  \
# 0                                                148
# 1                                                  0
# 2                                                  N
# 3                                                  0
# 4                                                  0
#
#   Hispanic: Not Hispanic or Latino!!Two or more races  \
# 0                                               2896
# 1                                               2230
# 2                                                  N
# 3                                               1269
# 4                                               1946
#
#   Hispanic: Not Hispanic or Latino!!Race_2+ Two races including Some other race  \
# 0                                                127
# 1                                                293
# 2                                                  N
# 3                                                  0
# 4                                                 56
#
#   Hispanic: Not Hispanic or Latino!!Race_2+ Two races excluding Some other race, and Three or more races  \
# 0                                               2769
# 1                                               1937
# 2                                                  N
# 3                                               1269
# 4                                               1890
#
#    Total housing units
# 0               116632
# 1                53888
# 2                38029
# 3                31656
# 4                34416

# %%
list(Demographics_Full.columns)
# Out:
# ['FIPS',
#  'total_pop',
#  '60plus',
#  'State',
#  'Area_name',
#  'Rural_urban_continuum_code_2013',
#  'Urban_influence_code_2013',
#  'Metro_2013',
#  'Civilian_labor_force_2018',
#  'Employed_2018',
#  'Unemployed_2018',
#  'Unemployment_rate_2018',
#  'Median_Household_Income_2018',
#  'Med_HH_Income_Percent_of_State_Total_2018',
#  'Area in square miles - Land area',
#  '2010 Density per square mile of land area - Population',
#  '2010 Density per square mile of land area - Housing units',
#  'Less than a high school diploma, 2014-18',
#  'High school diploma only, 2014-18',
#  "Some college or associate's degree, 2014-18",
#  "Bachelor's degree or higher, 2014-18",
#  'Percent of adults with less than a high school diploma, 2014-18',
#  'Percent of adults with a high school diploma only, 2014-18',
#  "Percent of adults completing some college or associate's degree, 2014-18",
#  "Percent of adults with a bachelor's degree or higher, 2014-18",
#  'Geographic Area Name',
#  'Total population',
#  'Male',
#  'Female',
#  'Under 5 years',
#  '5 to 9 years',
#  '10 to 14 years',
#  '15 to 19 years',
#  '20 to 24 years',
#  '25 to 34 years',
#  '35 to 44 years',
#  '45 to 54 years',
#  '55 to 59 years',
#  '60 to 64 years',
#  '65 to 74 years',
#  '75 to 84 years',
#  '85 years and over',
#  'Median age (years)',
#  'Under 18 years',
#  '16 years and over',
#  '18 years and over',
#  '21 years and over',
#  '62 years and over',
#  '65 years and over',
#  '18 years and over.1',
#  '18 years and over!!Male',
#  '18 years and over!!Female',
#  '65 years and over.1',
#  '65 years and over!!Male',
#  '65 years and over!!Female',
#  'Total population',
#  'One race',
#  'Two or more races',
#  'One race.1',
#  'Race_1 White',
#  'Race_1 Black or African American',
#  'Margin of Error!!Race_1 Black or African American',
#  'Race_1 American Indian and Alaska Native',
#  'Race_1 American Indian and Alaska Native!!Cherokee tribal grouping',
#  'Race_1 American Indian and Alaska Native!!Chippewa tribal grouping',
#  'Race_1 American Indian and Alaska Native!!Navajo tribal grouping',
#  'Race_1 American Indian and Alaska Native!!Sioux tribal grouping',
#  'Race_1 Asian',
#  'Race_1 Asian!!Asian Indian',
#  'Race_1 Asian!!Chinese',
#  'Race_1 Asian!!Filipino',
#  'Race_1 Asian!!Japanese',
#  'Race_1 Asian!!Korean',
#  'Race_1 Asian!!Vietnamese',
#  'Race_1 Asian!!Other Asian',
#  'Race_1 Native Hawaiian and Other Pacific Islander',
#  'Race_1 Native Hawaiian and Other Pacific Islander!!Native Hawaiian',
#  'Race_1 Native Hawaiian and Other Pacific Islander!!Guamanian or Chamorro',
#  'Race_1 Native Hawaiian and Other Pacific Islander!!Samoan',
#  'Race_1 Native Hawaiian and Other Pacific Islander!!Other Pacific Islander',
#  'Race_1 Some other race',
#  'Two or more races.1',
#  'Race_2+ White and Black or African American',
#  'Race_2+ White and American Indian and Alaska Native',
#  'Race_2+ White and Asian',
#  'Race_2+ Black or African American and American Indian and Alaska Native',
#  'Race_Total Total population',
#  'Race_Total White',
#  'Race_Total Black or African American',
#  'Race_Total American Indian and Alaska Native',
#  'Race_Total Asian',
#  'Race_Total Native Hawaiian and Other Pacific Islander',
#  'Race_Total Some other race',
#  'Hispanic: Total population',
#  'Hispanic: Hispanic or Latino (of any race)',
#  'Hispanic: Hispanic or Latino (of any race)!!Mexican',
#  'Hispanic: Hispanic or Latino (of any race)!!Puerto Rican',
#  'Hispanic: Hispanic or Latino (of any race)!!Cuban',
#  'Hispanic: Hispanic or Latino (of any race)!!Other Hispanic or Latino',
#  'Hispanic: Not Hispanic or Latino',
#  'Hispanic: Not Hispanic or Latino!!White alone',
#  'Hispanic: Not Hispanic or Latino!!Black or African American alone',
#  'Hispanic: Not Hispanic or Latino!!American Indian and Alaska Native alone',
#  'Hispanic: Not Hispanic or Latino!!Asian alone',
#  'Hispanic: Not Hispanic or Latino!!Native Hawaiian and Other Pacific Islander alone',
#  'Hispanic: Not Hispanic or Latino!!Some other race alone',
#  'Hispanic: Not Hispanic or Latino!!Two or more races',
#  'Hispanic: Not Hispanic or Latino!!Race_2+ Two races including Some other race',
#  'Hispanic: Not Hispanic or Latino!!Race_2+ Two races excluding Some other race, and Three or more races',
#  'Total housing units']

# %%
#Repeating similar process to above, but changing order of merges to make maximum rows
#Joining Education & Area
Educ_Area = pd.merge(Educ, Area_Houses, left_on='FIPS', right_on='County FIPS')
Educ_Area = Educ_Area.drop(columns=['County FIPS', 'Area in square miles - Total area', 'County Name'])
#Joining this with Population Data
Educ_Area_Pop = pd.merge(Educ_Area, County_Pop_Pop60, left_on='FIPS', right_on='FIPS')
#Joining this with Unemployment Data
Educ_Area_Pop_Unemp = pd.merge(Educ_Area_Pop, Unemp, left_on='FIPS', right_on='FIPS')
#Joining this with Poverty Data
Educ_Area_Pop_Unemp_Pov = pd.merge(Educ_Area_Pop_Unemp, Poverty, left_on='FIPS', right_on='FIPS')
#Joining this with Voting Data
Educ_Area_Pop_Unemp_Pov_Votes = pd.merge(Pop_Unemp_Area_Educ_Pov, Votes, left_on='FIPS', right_on='FIPS')

# %%
print('Educ_Area: ' + str(len(Educ_Area)))
print('Educ_Area_Pop: ' + str(len(Educ_Area_Pop)))
print('Educ_Area_Pop_Unemp: ' + str(len(Educ_Area_Pop_Unemp)))
print('Educ_Area_Pop_Unemp_Pov: ' + str(len(Educ_Area_Pop_Unemp_Pov)))
print('Educ_Area_Pop_Unemp_Pov_Votes: ' + str(len(Educ_Area_Pop_Unemp_Pov_Votes)) + '\n')
# Out:
# Educ_Area: 3219
# Educ_Area_Pop: 3140
# Educ_Area_Pop_Unemp: 3139
# Educ_Area_Pop_Unemp_Pov: 3134
# Educ_Area_Pop_Unemp_Pov_Votes: 3114

# %%
Educ_Area_Pop_Unemp_Pov_Votes.head()
# Out:
#    FIPS  total_pop  60plus State         Area_name_x  \
# 0  1001      55036   10523    AL  Autauga County, AL
# 1  1003     203360   53519    AL  Baldwin County, AL
# 2  1005      26201    6150    AL  Barbour County, AL
# 3  1007      22580    4773    AL     Bibb County, AL
# 4  1009      57667   13600    AL   Blount County, AL
#
#    Rural_urban_continuum_code_2013  Urban_influence_code_2013  Metro_2013  \
# 0                                2                          2           1
# 1                                3                          2           1
# 2                                6                          6           0
# 3                                1                          1           1
# 4                                1                          1           1
#
#   Civilian_labor_force_2018 Employed_2018 Unemployed_2018  \
# 0                    25,957        25,015             942
# 1                    93,849        90,456           3,393
# 2                     8,373         7,940             433
# 3                     8,661         8,317             344
# 4                    25,006        24,128             878
#
#    Unemployment_rate_2018 Median_Household_Income_2018  \
# 0                     3.6                     $59,338
# 1                     3.6                     $57,588
# 2                     5.2                     $34,382
# 3                     4.0                     $46,064
# 4                     3.5                     $50,412
#
#    Med_HH_Income_Percent_of_State_Total_2018  \
# 0                                      119.0
# 1                                      115.5
# 2                                       68.9
# 3                                       92.3
# 4                                      101.1
#
#    Area in square miles - Land area  \
# 0                            594.44
# 1                           1589.78
# 2                            884.88
# 3                            622.58
# 4                            644.78
#
#    2010 Density per square mile of land area - Population  \
# 0                                               91.8
# 1                                              114.6
# 2                                               31.0
# 3                                               36.8
# 4                                               88.9
#
#    2010 Density per square mile of land area - Housing units  \
# 0                                               37.2
# 1                                               65.5
# 2                                               13.4
# 3                                               14.4
# 4                                               37.0
#
#   Less than a high school diploma, 2014-18 High school diploma only, 2014-18  \
# 0                                    4,204                            12,119
# 1                                   14,310                            40,579
# 2                                    4,901                             6,486
# 3                                    2,650                             7,471
# 4                                    7,861                            13,489
#
#   Some college or associate's degree, 2014-18  \
# 0                                      10,552
# 1                                      46,025
# 2                                       4,566
# 3                                       3,846
# 4                                      13,267
#
#   Bachelor's degree or higher, 2014-18  \
# 0                               10,291
# 1                               46,075
# 2                                2,220
# 3                                1,813
# 4                                5,010
#
#    Percent of adults with less than a high school diploma, 2014-18  \
# 0                                               11.3
# 1                                                9.7
# 2                                               27.0
# 3                                               16.8
# 4                                               19.8
#
#    Percent of adults with a high school diploma only, 2014-18  \
# 0                                               32.6
# 1                                               27.6
# 2                                               35.7
# 3                                               47.3
# 4                                               34.0
#
#    Percent of adults completing some college or associate's degree, 2014-18  \
# 0                                               28.4
# 1                                               31.3
# 2                                               25.1
# 3                                               24.4
# 4                                               33.5
#
#    Percent of adults with a bachelor's degree or higher, 2014-18 Stabr  \
# 0                                               27.7                AL
# 1                                               31.3                AL
# 2                                               12.2                AL
# 3                                               11.5                AL
# 4                                               12.6                AL
#
#       Area_name_y  Rural-urban_Continuum_Code_2003  Urban_Influence_Code_2003  \
# 0  Autauga County                                2                          2
# 1  Baldwin County                                4                          5
# 2  Barbour County                                6                          6
# 3     Bibb County                                1                          1
# 4   Blount County                                1                          1
#
#    Rural-urban_Continuum_Code_2013  Urban_Influence_Code_2013 POVALL_2018  \
# 0                                2                          2       7,587
# 1                                3                          2      21,069
# 2                                6                          6       6,788
# 3                                1                          1       4,400
# 4                                1                          1       7,527
#
#   CI90LBAll_2018 CI90UBALL_2018  PCTPOVALL_2018  CI90LBALLP_2018  \
# 0          6,334          8,840            13.8             11.5
# 1         17,390         24,748             9.8              8.1
# 2          5,662          7,914            30.9             25.8
# 3          3,445          5,355            21.8             17.1
# 4          6,045          9,009            13.2             10.6
#
#    CI90UBALLP_2018 POV017_2018 CI90LB017_2018 CI90UB017_2018  PCTPOV017_2018  \
# 0             16.1       2,509          1,965          3,053            19.3
# 1             11.5       6,442          4,723          8,161            13.9
# 2             36.0       2,242          1,788          2,696            43.9
# 3             26.5       1,238            923          1,553            27.8
# 4             15.8       2,374          1,784          2,964            18.0
#
#    CI90LB017P_2018  CI90UB017P_2018 POV517_2018 CI90LB517_2018 CI90UB517_2018  \
# 0             15.1             23.5       1,891          1,469          2,313
# 1             10.2             17.6       4,534          3,223          5,845
# 2             35.0             52.8       1,411          1,056          1,766
# 3             20.7             34.9         840            606          1,074
# 4             13.5             22.5       1,520          1,053          1,987
#
#    PCTPOV517_2018  CI90LB517P_2018  CI90UB517P_2018 MEDHHINC_2018  \
# 0            19.5             15.1             23.9        59,338
# 1            13.1              9.3             16.9        57,588
# 2            36.7             27.5             45.9        34,382
# 3            26.3             19.0             33.6        46,064
# 4            15.5             10.7             20.3        50,412
#
#   CI90LBINC_2018 CI90UBINC_2018  (totalvotes, 2000)  (totalvotes, 2004)  \
# 0         53,628         65,048             17208.0             20081.0
# 1         54,437         60,739             56480.0             69320.0
# 2         31,157         37,607             10395.0             10777.0
# 3         41,283         50,845              7101.0              7600.0
# 4         46,157         54,667             17973.0             21504.0
#
#    (totalvotes, 2008)  (totalvotes, 2012)  (totalvotes, 2016)  \
# 0             23641.0             23932.0             24973.0
# 1             81413.0             85338.0             95215.0
# 2             11630.0             11509.0             10469.0
# 3              8644.0              8420.0              8819.0
# 4             24267.0             24006.0             25588.0
#
#    (Prop_Blue, 2000)  (Prop_Blue, 2004)  (Prop_Blue, 2008)  (Prop_Blue, 2012)  \
# 0           0.287192           0.236940           0.257730           0.265878
# 1           0.247822           0.225029           0.238119           0.215894
# 2           0.499086           0.448362           0.489854           0.513685
# 3           0.381636           0.274868           0.265965           0.261520
# 4           0.276915           0.183129           0.145135           0.123719
#
#    (Prop_Blue, 2016)
# 0           0.237697
# 1           0.193856
# 2           0.465278
# 3           0.212496
# 4           0.084258
