# %%
import pandas as pd
import numpy as np
import os

# %%
#Loading in County Data
Educ = pd.read_csv('../../../../data/us/demographics/education.csv', encoding='latin1')
State_Pop = pd.read_csv('../../../../data/us/demographics/state_populations.csv', encoding='latin1')

# %%
#State Education levels
Educ_State = Educ[Educ['FIPS'] % 1000 == 0]

# %%
Educ_State.head()
# Out:
#      FIPS Less than a high school diploma, 2014-18  \
# 0       0                               26,948,057
# 1    1000                                  470,043
# 69   2000                                   34,760
# 106  4000                                  613,002
# 122  5000                                  276,029
#
#     High school diploma only, 2014-18  \
# 0                          59,265,308
# 1                           1,020,172
# 69                            133,851
# 106                         1,112,551
# 122                           681,223
#
#     Some college or associate's degree, 2014-18  \
# 0                                    63,365,655
# 1                                       987,148
# 69                                      169,471
# 106                                   1,570,308
# 122                                     590,434
#
#     Bachelor's degree or higher, 2014-18  \
# 0                             68,867,051
# 1                                822,595
# 69                               139,645
# 106                            1,338,071
# 122                              451,621
#
#      Percent of adults with less than a high school diploma, 2014-18  \
# 0                                                 12.3
# 1                                                 14.2
# 69                                                 7.3
# 106                                               13.2
# 122                                               13.8
#
#      Percent of adults with a high school diploma only, 2014-18  \
# 0                                                 27.1
# 1                                                 30.9
# 69                                                28.0
# 106                                               24.0
# 122                                               34.1
#
#      Percent of adults completing some college or associate's degree, 2014-18  \
# 0                                                 29.0
# 1                                                 29.9
# 69                                                35.5
# 106                                               33.9
# 122                                               29.5
#
#      Percent of adults with a bachelor's degree or higher, 2014-18
# 0                                                 31.5
# 1                                                 24.9
# 69                                                29.2
# 106                                               28.9
# 122                                               22.6

# %%
State_Pop.head()
# Out:
#   state country  population
# 0    CA     USA    39512223
# 1    TX     USA    28995881
# 2    FL     USA    21477737
# 3    NY     USA    19453561
# 4    PA     USA    12801989
