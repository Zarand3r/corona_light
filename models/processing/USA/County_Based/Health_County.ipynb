# %%
import pandas as pd
import numpy as np
import os

# %%
import git
import sys
repo = git.Repo("./", search_parent_directories=True)
homedir = repo.working_dir

# %%
County_Beds = pd.read_csv(f"{homedir}/data/us/hospitals/beds_by_county.csv", encoding='latin1')
County_ICU = pd.read_csv(f"{homedir}/data/us/hospitals/icu_county.csv", encoding='latin1')

# %%
County_ICU
# Out:
#        FIPS  hospitals  icu_beds
# 0      1001          1         6
# 1      1003          3        51
# 2      1005          1         5
# 3      1007          1         0
# 4      1009          1         6
# 5      1011          1         0
# 6      1013          1         7
# 7      1015          2        24
# 8      1017          0         0
# 9      1019          1         0
# 10     1021          1         6
# 11     1023          1         0
# 12     1025          2         0
# 13     1027          1         4
# 14     1029          0         0
# 15     1031          1         7
# 16     1033          2        22
# 17     1035          1         0
# 18     1037          0         0
# 19     1039          2        13
# 20     1041          1         0
# 21     1043          1        12
# 22     1045          1         6
# 23     1047          1        18
# 24     1049          1        12
# 25     1051          2         5
# 26     1053          2        14
# 27     1055          2        56
# 28     1057          2        12
# 29     1059          2         7
# ...     ...        ...       ...
# 3112  55129          2         0
# 3113  55131          2        12
# 3114  55133          4        64
# 3115  55135          2         4
# 3116  55137          1         0
# 3117  55139          2        26
# 3118  55141          2        27
# 3119  56001          1         4
# 3120  56003          2         0
# 3121  56005          1        14
# 3122  56007          1         6
# 3123  56009          1         0
# 3124  56011          1         0
# 3125  56013          1        12
# 3126  56015          1         0
# 3127  56017          1         0
# 3128  56019          1         0
# 3129  56021          1        15
# 3130  56023          2         0
# 3131  56025          2        14
# 3132  56027          1         0
# 3133  56029          2         4
# 3134  56031          1         0
# 3135  56033          1        11
# 3136  56035          0         0
# 3137  56037          2        10
# 3138  56039          1         6
# 3139  56041          1         6
# 3140  56043          1         0
# 3141  56045          1         0
#
# [3142 rows x 3 columns]

# %%
#Cleaning beds Data
County_Beds = County_Beds.sort_values(by=['FIPS'])
#Dropping unecessary columns
County_Beds = County_Beds.drop(columns=['state', 'county', 'Name'])

# %%
#Cleaning icu Data
County_ICU = County_ICU.sort_values(by=['FIPS'])

# %%
#Merging Hospital Data with ICU Data
County_Health = County_ICU.join(County_Beds.set_index('FIPS'), on='FIPS', lsuffix='_Post', rsuffix='_Pre')
#Cleaning Merged Dataset
County_Health = County_Health[['FIPS','hospitals','staffed_beds','licensed_beds','icu_beds_Pre','icu_beds_Post']]

#Removing NaNs
County_Health = County_Health[County_Health.staffed_beds >= -1]

County_Health = County_Health.sort_values(by=['FIPS'])
County_Health = County_Health.set_index('FIPS')

County_Health.to_csv('County_Health.csv')

# %%
#Setting FIPS to main index
County_Beds = County_Beds.set_index('FIPS')
County_Beds.to_csv('County_Beds.csv')

County_ICU = County_ICU.set_index('FIPS')
County_ICU.to_csv('County_ICU.csv')

# %%
print('County_ICU: ' + str(len(County_ICU)))
print('County_Beds: ' + str(len(County_Beds)))
print('County_Health: ' + str(len(County_Health)))
# Out:
# County_ICU: 3142
# County_Beds: 2512
# County_Health: 2483

# %%
County_Beds.head()
# Out:
#       staffed_beds  licensed_beds  icu_beds
# FIPS
# 1001            55             85         6
# 1003           362            410        44
# 1005            30             74         5
# 1007            25             35         0
# 1009            25             40         6

# %%
County_ICU.head()
# Out:
#       hospitals  icu_beds
# FIPS
# 1001          1         6
# 1003          3        51
# 1005          1         5
# 1007          1         0
# 1009          1         6

# %%
County_Health.head()
# Out:
#       hospitals  staffed_beds  licensed_beds  icu_beds_Pre  icu_beds_Post
# FIPS
# 1001          1          55.0           85.0           6.0              6
# 1003          3         362.0          410.0          44.0             51
# 1005          1          30.0           74.0           5.0              5
# 1007          1          25.0           35.0           0.0              0
# 1009          1          25.0           40.0           6.0              6
